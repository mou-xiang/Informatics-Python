# %% [markdown]
# # Task1

# %%
print("Sun Ruxiang")
print("25320520")
# Out:
# Sun Ruxiang
# 25320520

# %% [markdown]
# # Task2

# %%
#one-line comment
'''
Multiline
comment
'''
#Example of working with integers
a = 15
b = 7
print("a = ", a)
print("b = ", b)
print("a + b = ", a + b) # addition
print("a - b = ", a - b) # subtraction
print("a * b = ", a * b) # multiplication
print("a / b = ", a / b) # division
print("a // b = ", a // b) # division with rounding down to an integer
print("a % b = ", a % b) # remainder of division (mod)
print("a ** b = ", a ** b) # exponentiation (power)
#converting the int type to float
a1 = float(a)
print("a1 = ", a1)
print("\n")
# Out:
# a =  15
# b =  7
# a + b =  22
# a - b =  8
# a * b =  105
# a / b =  2.142857142857143
# a // b =  2
# a % b =  1
# a ** b =  170859375
# a1 =  15.0

# %% [markdown]
# # Task3

# %%
#Example of working with real numbers<br>
c = 3.5
d = 6.9
print("c = ", c)
print("d = ", d)
print("c + d = ", c + d) # addition
print("c * d = ", c * d) # multiplication
print("c / d = ", c / d) # division
d1 = 2.3e-5
print("d1 = ",d1)
print("c + d1 = ", c + d1) # addition
#converting the float type to int type
d2 = int(d)
print("d2 = ",d2)
print("\n") #line break
#converting the numbers between different numeral systems
#with help of int()
st = '11222'
d3 = int(st, 4) #the second element is the base of sourse numeral system
print("d2 = ",d2)
print("\n") #line break
# Out:
# c =  3.5
# d =  6.9
# c + d =  10.4
# c * d =  24.150000000000002
# c / d =  0.5072463768115941
# d1 =  2.3e-05
# c + d1 =  3.500023
# d2 =  6
#
#
# d2 =  6

# %% [markdown]
# # Task4

# %%
#Assignment operators<br>
e = 7
print("e = 7: ", e)
e += 3
print("e += 3: ", e)
e -= 3
print("e -= 3: ", e)
e *= 15
print("e *= 5: ", e)
e /= 4
print("e /= 4: ", e)
e //= 2
print("e //= 2: ", e)
e %= 5
print("e %= 5: ", e)
e **= 3
print("e **= 3: ", e)
print("\n")
# Out:
# e = 7:  7
# e += 3:  10
# e -= 3:  7
# e *= 5:  105
# e /= 4:  26.25
# e //= 2:  13.0
# e %= 5:  3.0
# e **= 3:  27.0

# %% [markdown]
# # Task5

# %%
# define the variable
z = 3
y = 5
result = 0

# do addition
result = z + y
print("z + y= ",result)

# do substraction
result = z - y
print("z - y = ",result)

# do multiplication
result = z * y
print("z * y = ",result)

# do division
result = z / y
print("z / y = ",result)

# do division with round down
result = z // y
print("z // y = ",result)

# do calculation for remainder of the division
result = z % y
print("z % y = ",result)

# do exponentation
result = z ** y
print("z ** y = ",result)
# Out:
# z + y=  8
# z - y =  -2
# z * y =  15
# z / y =  0.6
# z // y =  0
# z % y =  3
# z ** y =  243

# %% [markdown]
# # Task6

# %%
# define x, v
x = 105
y = 58

# divide with conversion to real type
result = int(x / y)
print("x / y = ",result,"integral type")

# divide without conversion
result = float(x / y)
print("x / y = ",result,"real type")
# Out:
# x / y =  1 integral type
# x / y =  1.8103448275862069 real type

# %% [markdown]
# # Task7

# %%
#Logical operations
f = True
g = False
print("f: ", f)
print("not f: ", not f)
print("f and g:", f and g)
# print("form:", form)
print("f == g: ", f == g)
print("f != g: ", f != g)
print("\n")
h = 3
i = 5
print("h = ", h)
print("i = ", i)
print("h > i: ", h > i)
print("h < i: ", h < i)
print("h>= i:", h>= i)
print("0 < h<= i:", 0 <h<=i)
print("\n\n")
# Out:
# f:  True
# not f:  False
# f and g: False
# f == g:  False
# f != g:  True
#
#
# h =  3
# i =  5
# h > i:  False
# h < i:  True
# h>= i: False
# 0 < h<= i: True

# %% [markdown]
# # Task8

# %%
#Bitwise operations

j = 7
k = 20

print("j = %d; j in binary format: %s" % (j, bin(j)))
print("k = %d; k in binary format: %s" % (k, bin(k)))
#Bitwise AND
print("j & k: %d; binary: %s" % (j & k, bin(j & k)))
#Bitwise OR
print("j | k: %d; binary: %s" % (j | k, bin(j | k)))
#Bitwise XOR
print("j ^ k: %d; binary: %s" % (j ^ k, bin(j ^ k)))
#binary number inversion
print("~k: %d; binary: %s" % (~k, bin(~k)))
#shift one bit to the right
print("k>>1: %d; binary: %s" % (k>>1, bin(k>>1)))
#shift one bit to the left
print("k<<1: %d; binary: %s" % (k<<1, bin(k<<1)))
print("\n\n")
# Out:
# j = 7; j in binary format: 0b111
# k = 20; k in binary format: 0b10100
# j & k: 4; binary: 0b100
# j | k: 23; binary: 0b10111
# j ^ k: 19; binary: 0b10011
# ~k: -21; binary: -0b10101
# k>>1: 10; binary: 0b1010
# k<<1: 40; binary: 0b101000

# %% [markdown]
# # Task9,10,11

# %%
A, B = 1, 2
C, D = True, False

# for task10
print("not(C and D): ", not(C and D))
print("C and D or not(C and D): ", C and D or not(C and D))
print("not(C) or D: ", not(C) or D)

# for task11
print("A<=B: ", A<=B)
print("A>B or A==B: ", A>B or A==B)
print("not(A<B): ", not(A<B))
# Out:
# not(C and D):  True
# C and D or not(C and D):  True
# not(C) or D:  False
# A<=B:  True
# A>B or A==B:  False
# not(A<B):  False

# %% [markdown]
# # Task12,13,14

# %%
# define the variable
s = 154
p = 6

# print
print(f"s = {s} in decimal, {bin(s)} in binary")
print(f"p = {p} in decimal, {bin(p)} in binary")
# Out:
# s = 154 in decimal, 0b10011010 in binary
# p = 6 in decimal, 0b110 in binary

# %%
# for Task13
s = bin(s) or bin(p)
decimal_value = int(s[2:], 2)
print(f"result of s | p in decimal: {decimal_value}")
print(f"result of s | p in binary: {s}")
# Out:
# result of s | p in decimal: 154
# result of s | p in binary: 0b10011010

# %%
# for Task14
s = 154
p = 6

s_shifted = s >> 2
print(f"s shifted right by 2 in decimal: {s_shifted}")
print(f"s shifted right by 2 in binary: {bin(s_shifted)}")
p_shifted = p >> 2
print(f"p shifted right by 2 in decimal: {p_shifted}")
print(f"p shifted right by 2 in binary: {bin(p_shifted)}")
# Out:
# s shifted right by 2 in decimal: 38
# s shifted right by 2 in binary: 0b100110
# p shifted right by 2 in decimal: 1
# p shifted right by 2 in binary: 0b1

# %% [markdown]
# # Task15

# %%
m = 10
pi = 3.1415927
print("m = ",m)
print("m = %d" % m)
print("%7d" % m)
print("pi = ", pi)
print("%.3f" % pi)
print("%10.4f\n" % pi)
print("m = {}, pi = {}".format(m,pi))
ch = 'A'
print("ch = %c" % ch)
s = "Hello"
print("s = %s" % s)
print("\n\n")
code = input("Enter your position number in group: ")
n1, n2 = input("Enter two numbers splitted by space:").split()
d, m, y = input("Enter three numbers splitted by \'.\': ").split('.')
print("{} + {} = {}".format(n1,n2,float(n1)+float(n2)))
print("Your birthday is %s.%s.%s and you are %d in the group list" % (d,m,y,int(code)) )
# Out:
# m =  10
# m = 10
#      10
# pi =  3.1415927
# 3.142
#     3.1416
#
# m = 10, pi = 3.1415927
# ch = A
# s = Hello
#
#
#
# 1 + 2 = 3.0
# Your birthday is 1.2.3 and you are 2 in the group list

# %% [markdown]
# # Task16

# %%
print("m = %.4f; pi = %.3f" % (float(m), float(pi)))
# Out:
# m = 2.0000; pi = 3.142

# %% [markdown]
# # Task17

# %%
print("m = {}; pi = {}".format(m, pi))
# Out:
# m = 2; pi = 3.1415927

# %% [markdown]
# # Task18

# %%
i1, c1= (input("Enter score in Informatics: ").split(","))

print("i1 = {}; c1 = {}".format(i1, c1))
# Out:
# i1 = 100; c1 = 90

# %% [markdown]
# # Task19

# %%
num_str = input("Enter a number: ")
num_int = int(num_str)
# calculate the base
birthday_num = int(input("birthday number: "))
num_base = birthday_num % 8
# convert num
num_converted = int(num_str, num_base)
print(f"Number {num_str} in base {num_base} is {num_converted} in decimal.")
# Out:
# Number 123456123456 in base 7 is 2691243750 in decimal.

# %% [markdown]
# # Task20

# %%
dec_num = int(input("Enter a decimal number: "))
bin_num = bin(dec_num)
# multiply and divide using bitwise operators
result_mul = dec_num << 1  # multiply by 2
result_div = dec_num >> 3  # divide by 8
print(f"result of multiplying {dec_num} by 2 is {result_mul} in decimal, {bin(result_mul)} in binary.")
print(f"result of dividing {dec_num} by 8 is {result_div} in decimal, {bin(result_div)} in binary.")
# Out:
# result of multiplying 16 by 2 is 32 in decimal, 0b100000 in binary.
# result of dividing 16 by 8 is 2 in decimal, 0b10 in binary.
